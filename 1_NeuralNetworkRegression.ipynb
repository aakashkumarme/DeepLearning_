# %% [markdown]
# <a href="https://colab.research.google.com/github/aakashkumarme/DeepLearning_/blob/main/1_NeuralNetworkRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Neural Network Regression**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.4.1'

# %%
import numpy as np
import matplotlib.pyplot as plt

X  = np.array([-7.0,-4.0,-1.0,2.0,5.0,8.0,11.0,14.0])

y = np.array([3.0,6.0,9.0,12.0,15.0,18.0,21.0,24.0])

plt.scatter(X,y);

# %%
X = tf.constant(X)
y = tf.constant(y)
X,y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float64, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.])>,
#  <tf.Tensor: shape=(8,), dtype=float64, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.])>)

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential([
                             tf.keras.layers.Dense(1)
])

model.compile(loss = tf.keras.losses.mae,
              optimizer = tf.keras.optimizers.SGD(),
              metrics = ["mae"])

model.fit(X,y,epochs = 5)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 3s 3s/step - loss: 11.5048 - mae: 11.5048
# Epoch 2/5
# 1/1 [==============================] - 0s 5ms/step - loss: 11.3723 - mae: 11.3723
# Epoch 3/5
# 1/1 [==============================] - 0s 8ms/step - loss: 11.2398 - mae: 11.2398
# Epoch 4/5
# 1/1 [==============================] - 0s 5ms/step - loss: 11.1073 - mae: 11.1073
# Epoch 5/5
# 1/1 [==============================] - 0s 8ms/step - loss: 10.9748 - mae: 10.9748

# %%
model.predict([17.0])
# Out:
# array([[12.716021]], dtype=float32)

# %%
#increase epoch
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(1)
])

model.compile(loss = tf.keras.losses.mae,
              optimizer = tf.keras.optimizers.SGD(),
              metrics = ["mae"])

model.fit(X,y,epochs = 100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 300ms/step - loss: 11.2219 - mae: 11.2219
# Epoch 2/100
# 1/1 [==============================] - 0s 4ms/step - loss: 11.0894 - mae: 11.0894
# Epoch 3/100
# 1/1 [==============================] - 0s 5ms/step - loss: 10.9569 - mae: 10.9569
# Epoch 4/100
# 1/1 [==============================] - 0s 5ms/step - loss: 10.8244 - mae: 10.8244
# Epoch 5/100
# 1/1 [==============================] - 0s 5ms/step - loss: 10.6919 - mae: 10.6919
# Epoch 6/100
# 1/1 [==============================] - 0s 5ms/step - loss: 10.5594 - mae: 10.5594
# Epoch 7/100
# 1/1 [==============================] - 0s 9ms/step - loss: 10.4269 - mae: 10.4269
# Epoch 8/100
# 1/1 [==============================] - 0s 4ms/step - loss: 10.2944 - mae: 10.2944
# Epoch 9/100
# 1/1 [==============================] - 0s 5ms/step - loss: 10.1619 - mae: 10.1619
# Epoch 10/100
# 1/1 [==============================] - 0s 8ms/step - loss: 10.0294 - mae: 10.0294
# Epoch 11/100
# ...

# %%
model.predict([17.0])
# Out:
# array([[29.739855]], dtype=float32)

# %%
#Create a demo tensor for housing price prediction problem
house_info =  tf.constant(["bedroom","bathroom","garage"])
house_price =  ([939700])
house_info,house_price
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'bedroom', b'bathroom', b'garage'], dtype=object)>,
#  [939700])

# %%
#increase a hidden layer
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(100,activation="relu"),
                             tf.keras.layers.Dense(1)
])

model.compile(loss = tf.keras.losses.mae,
              optimizer = tf.keras.optimizers.Adam(learning_rate=0.01),
              metrics = ["mae"])

model.fit(X,y,epochs = 100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 398ms/step - loss: 13.0842 - mae: 13.0842
# Epoch 2/100
# 1/1 [==============================] - 0s 6ms/step - loss: 12.1504 - mae: 12.1504
# Epoch 3/100
# 1/1 [==============================] - 0s 5ms/step - loss: 11.1886 - mae: 11.1886
# Epoch 4/100
# 1/1 [==============================] - 0s 5ms/step - loss: 10.2380 - mae: 10.2380
# Epoch 5/100
# 1/1 [==============================] - 0s 5ms/step - loss: 9.4843 - mae: 9.4843
# Epoch 6/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.7138 - mae: 8.7138
# Epoch 7/100
# 1/1 [==============================] - 0s 5ms/step - loss: 7.9227 - mae: 7.9227
# Epoch 8/100
# 1/1 [==============================] - 0s 5ms/step - loss: 7.1122 - mae: 7.1122
# Epoch 9/100
# 1/1 [==============================] - 0s 6ms/step - loss: 6.2749 - mae: 6.2749
# Epoch 10/100
# 1/1 [==============================] - 0s 5ms/step - loss: 5.4108 - mae: 5.4108
# Epoch 11/100
# ...

# %%
model.predict([17.0])
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fa9b7421440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[26.750233]], dtype=float32)

# %% [markdown]
# ### Common ways to improve a model:
#
#
# 1.   Adding layers
# 2.   Increase hidden unit
# 3.   Change activation function
# 4.   Change optimization function
# 5.   Change the learning rate
# 6.   Fitting more data

# %% [markdown]
# ###Evaluating our model

# %%
X = tf.range(-100,100,4)
X
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#         -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#         -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#          32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#          76,   80,   84,   88,   92,   96], dtype=int32)>

# %%
y = X+10
y
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
X_train = X[0:40]
y_train = y[0:40]

X_test = X[40:50]
y_test = y[40:50]

# %%
plt.figure(figsize = (5,3))
plt.scatter(X_train,y_train, color = 'blue' , label = "Training Data")
plt.scatter(X_test,y_test, color = 'green' , label = "Testing Data")

# %%
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(1)
])

model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"]
              )


model.fit(X_train,y_train,epochs =100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 10ms/step - loss: 8.4411 - mae: 8.4411
# Epoch 2/100
# 2/2 [==============================] - 0s 7ms/step - loss: 10.1746 - mae: 10.1746
# Epoch 3/100
# 2/2 [==============================] - 0s 5ms/step - loss: 10.8905 - mae: 10.8905
# Epoch 4/100
# 2/2 [==============================] - 0s 7ms/step - loss: 8.8454 - mae: 8.8454
# Epoch 5/100
# 2/2 [==============================] - 0s 7ms/step - loss: 9.9702 - mae: 9.9702
# Epoch 6/100
# 2/2 [==============================] - 0s 7ms/step - loss: 9.6662 - mae: 9.6662
# Epoch 7/100
# 2/2 [==============================] - 0s 4ms/step - loss: 8.5367 - mae: 8.5367
# Epoch 8/100
# 2/2 [==============================] - 0s 6ms/step - loss: 9.1883 - mae: 9.1883
# Epoch 9/100
# 2/2 [==============================] - 0s 7ms/step - loss: 19.7696 - mae: 19.7696
# Epoch 10/100
# 2/2 [==============================] - 0s 8ms/step - loss: 9.7770 - mae: 9.7770
# Epoch 11/100
# ...

# %%
model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_17 (Dense)             (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
X[0],y[0]
# Out:
# (<tf.Tensor: shape=(), dtype=int32, numpy=-100>,
#  <tf.Tensor: shape=(), dtype=int32, numpy=-90>)

# %%
tf.random.set_seed(42)
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(1,input_shape=[1])
])

model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"]
              )


model.fit(X_train,y_train,epochs =100)

# %%
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_18 (Dense)             (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model=model,show_shapes='TRUE')

# %%
tf.random.set_seed(42)
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(10,input_shape=[1] , name = "input_layer"),
                             tf.keras.layers.Dense(1, name = "output_layer")
],name = "model_name_goes_here_voila")

model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              metrics=["mae"]
              )


model.fit(X_train,y_train,epochs =100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 9ms/step - loss: 25.1017 - mae: 25.1017
# Epoch 2/100
# 2/2 [==============================] - 0s 4ms/step - loss: 19.5055 - mae: 19.5055
# Epoch 3/100
# 2/2 [==============================] - 0s 10ms/step - loss: 13.6854 - mae: 13.6854
# Epoch 4/100
# 2/2 [==============================] - 0s 7ms/step - loss: 8.7648 - mae: 8.7648
# Epoch 5/100
# 2/2 [==============================] - 0s 8ms/step - loss: 8.5096 - mae: 8.5096
# Epoch 6/100
# 2/2 [==============================] - 0s 7ms/step - loss: 10.7805 - mae: 10.7805
# Epoch 7/100
# 2/2 [==============================] - 0s 8ms/step - loss: 11.7563 - mae: 11.7563
# Epoch 8/100
# 2/2 [==============================] - 0s 7ms/step - loss: 11.6058 - mae: 11.6058
# Epoch 9/100
# 2/2 [==============================] - 0s 8ms/step - loss: 11.3091 - mae: 11.3091
# Epoch 10/100
# 2/2 [==============================] - 0s 7ms/step - loss: 10.0867 - mae: 10.0867
# Epoch 11/100
# ...

# %%
model.summary()
# Out:
# Model: "model_name_goes_here_voila"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_layer (Dense)          (None, 10)                20
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 11
# ...
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model=model,show_shapes='TRUE')

# %%
y_pred = model.predict(X_test)
# Out:
# WARNING:tensorflow:8 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fa96a370e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
plt.scatter(X_train,y_train, color = 'blue' , label = "Training Data")
plt.scatter(X_test,y_test, color = 'green' , label = "Testing Data")
plt.scatter(X_test,y_pred,color='red',label = "Predictions")

# %% [markdown]
# #Evaluating model prediction with metrics

# %% [markdown]
# 1.   MAE
# 2.   MSE - Use larger errors are more significant than smaller ones.
# 3.   Huber - Combinaion of MAE and MSE
# ![image.png](data:image/png;base64,...)
# Tensors

# %%
#Tensor need to be in right shape and format for comparison

model.evaluate(X_test,y_test)
# Out:
# 1/1 [==============================] - 0s 30ms/step - loss: 3.1413 - mae: 3.1413
# [3.1413168907165527, 3.1413168907165527]

# %%
y_pred = tf.constant(y_pred)
y_pred = tf.squeeze(y_pred)
y_pred
# Out:
# <tf.Tensor: shape=(10,), dtype=float32, numpy=
# array([ 72.428246,  76.58671 ,  80.74516 ,  84.90362 ,  89.06209 ,
#         93.22055 ,  97.37901 , 101.537476, 105.69592 , 109.854385],
#       dtype=float32)>

# %%
y_test
# Out:
# <tf.Tensor: shape=(10,), dtype=int32, numpy=array([ 70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
tf.keras.losses.MAE(y_test,y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=3.141317>

# %%
tf.metrics.mean_absolute_error(y_test,y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=3.141317>

# %%
tf.metrics.mean_squared_error(y_test,y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=10.075027>

# %%
def mae(y_true,y_pred):
  return tf.metrics.mean_absolute_error(y_true=y_true,
                                        y_pred=y_pred)

def mse(y_true,y_pred):
  return tf.metrics.mean_squared_error(y_true=y_true,
                                        y_pred=y_pred)

# %% [markdown]
# #Running experiments to improve our model
#
#
#
# *   Get more data
# *   Make model complex by adding layers/hiden units
# *   Train longer

# %% [markdown]
# #Save the model
# 1) SavedModel Format
# 2)HDF5 format

# %%
#save model format
model.save("bestRegressionModel")
# Out:
# INFO:tensorflow:Assets written to: bestRegressionModel/assets

# %%
#HDF5 format
model.save("bestRegressionModel.h5")

# %%
load_saved_model = tf.keras.models.load_model("/content/bestRegressionModel.h5")
load_saved_model.summary()
# Out:
# Model: "model_name_goes_here_voila"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_layer (Dense)          (None, 10)                20
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 11
# ...
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________
